# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
iris = sns.load_dataset('iris')

# %%
iris.shape
iris.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
iris.columns = ['sl','sw','pl','pw','sp']
iris.columns
# Out:
# Index(['sl', 'sw', 'pl', 'pw', 'sp'], dtype='object')

# %%
iris.head()
# Out:
#     sl   sw   pl   pw      sp
# 0  5.1  3.5  1.4  0.2  setosa
# 1  4.9  3.0  1.4  0.2  setosa
# 2  4.7  3.2  1.3  0.2  setosa
# 3  4.6  3.1  1.5  0.2  setosa
# 4  5.0  3.6  1.4  0.2  setosa

# %%
iris.__class__
# Out:
# pandas.core.frame.DataFrame

# %%
iris.sp.__class__
# Out:
# pandas.core.series.Series

# %%
iris.sp
# Out:
# 0         setosa
# 1         setosa
# 2         setosa
# 3         setosa
# 4         setosa
#          ...
# 145    virginica
# 146    virginica
# 147    virginica
# 148    virginica
# 149    virginica
# Name: sp, Length: 150, dtype: object

# %%
iris.sp.dtype
# Out:
# dtype('O')

# %%
iris.sp = pd.Categorical(iris.sp)
iris.sp
# Out:
# 0         setosa
# 1         setosa
# 2         setosa
# 3         setosa
# 4         setosa
#          ...
# 145    virginica
# 146    virginica
# 147    virginica
# 148    virginica
# 149    virginica
# Name: sp, Length: 150, dtype: category
# Categories (3, object): ['setosa', 'versicolor', 'virginica']

# %%
iris.sp.dtype
# Out:
# CategoricalDtype(categories=['setosa', 'versicolor', 'virginica'], ordered=False, categories_dtype=object)

# %%
from plotnine import *

# %%
# ggplot(iris)+
#   geom_point(aes(sw,sl,col=sp))+
#   geom_smooth(aes(sw,sl),method="lm", se=F )

# %%
( 
  ggplot(iris)+
   geom_point( aes(x="sw", y="sl", color="sp") )+
   geom_smooth( aes(x="sw", y="sl",color="sp"),
       method="lm", se=False ) 
)
# Out:
# <Figure Size: (640 x 480)>

# %%
( 
   ggplot(iris) + 
      geom_point( aes( x="sw", y="sl" ) ) +
      geom_smooth( aes( x="sw", y="sl" ), 
         method="lm", se=False )
      
)
# Out:
# <Figure Size: (640 x 480)>
